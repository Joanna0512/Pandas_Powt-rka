# %% [markdown]
# <a href="https://colab.research.google.com/github/Joanna0512/Pandas_Powt-rka/blob/main/04_04_23_Powt%C3%B3rka_z_przetwarzania_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
dates =pd.date_range('20220201', periods=6)

# %%
df=pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2022-02-01 -0.607781  0.944500 -1.406782 -0.765897
# 2022-02-02  0.200609  0.279967  0.987110 -0.601329
# 2022-02-03  1.334081 -1.749429 -0.698679 -0.089751
# 2022-02-04 -0.540572  0.014233 -1.334514  0.714809
# 2022-02-05 -1.388840  0.283478  1.503813 -1.873191
# 2022-02-06  1.347957  1.632543  0.179441 -2.176252

# %%
data=[10,20,30,40,50,60, 70, 80]
df=pd.DataFrame(data, columns=['Numbers'])
df
# Out:
#    Numbers
# 0       10
# 1       20
# 2       30
# 3       40
# 4       50
# 5       60
# 6       70
# 7       80

# %%
df.replace(to_replace=80, value=0, inplace=True) #zmiana wybranej wartości na inną

# %%
df
# Out:
#    Numbers
# 0       10
# 1       20
# 2       30
# 3       40
# 4       50
# 5       60
# 6       70
# 7        0

# %%
df.dtypes
# Out:
# Numbers    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Numbers  8 non-null      int64
# dtypes: int64(1)
# memory usage: 192.0 bytes

# %%
list = [["ania", 12], ["kasia", 15], ["tomek", 10]]
df=pd.DataFrame(list, columns=["Name", "Age"])

# %%
df
# Out:
#     Name  Age
# 0   ania   12
# 1  kasia   15
# 2  tomek   10

# %% [markdown]
# Tworzenie DateFrame ze słownika

# %%
scores = {"ania": 12, "kasia":15, "tomek":10, 'maciek':22, "zuza":89, 'ala': 77, 'paweł': 55, 'maks':43, 'asia':45, 'iza': 99}
scores_df=pd.DataFrame(scores.items(), columns=["Imię", "Liczba punktów"])

# %%
scores_df
# Out:
#      Imię  Liczba punktów
# 0    ania              12
# 1   kasia              15
# 2   tomek              10
# 3  maciek              22
# 4    zuza              89
# 5     ala              77
# 6   paweł              55
# 7    maks              43
# 8    asia              45
# 9     iza              99

# %%
scores_df.sort_values(by="Liczba punktów")#tu widać stare indexy
# Out:
#      Imię  Liczba punktów
# 2   tomek              10
# 0    ania              12
# 1   kasia              15
# 3  maciek              22
# 7    maks              43
# 8    asia              45
# 6   paweł              55
# 5     ala              77
# 4    zuza              89
# 9     iza              99

# %%
scores_df.reset_index(drop=True) #nowe indeksy
# Out:
#      Imię  Liczba punktów
# 0    ania              12
# 1   kasia              15
# 2   tomek              10
# 3  maciek              22
# 4    zuza              89
# 5     ala              77
# 6   paweł              55
# 7    maks              43
# 8    asia              45
# 9     iza              99

# %%
scores_df=scores_df.sort_values(by=['Liczba punktów', 'Imię'], ascending=[False, False])

# %%
scores_df
# Out:
#      Imię  Liczba punktów
# 9     iza              99
# 4    zuza              89
# 5     ala              77
# 6   paweł              55
# 8    asia              45
# 7    maks              43
# 3  maciek              22
# 1   kasia              15
# 0    ania              12
# 2   tomek              10

# %%
! git clone https://github.com/matzim95/ML-datasets
# Out:
# Cloning into 'ML-datasets'...
# remote: Enumerating objects: 194, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 194 (delta 33), reused 124 (delta 24), pack-reused 60
# Receiving objects: 100% (194/194), 35.45 MiB | 15.79 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
titanic = pd.read_csv('ML-datasets/titanic.csv', sep=';') #wyświetlanie nazw kolumn po przecinku

# %%
titanic
# Out:
#     PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 0    1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/...
# 1    2,1,1,"Cumings, Mrs. John Bradley (Florence Br...
# 2    3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,S...
# 3    4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May ...
# 4    5,0,3,"Allen, Mr. William Henry",male,35,0,0,3...
# ..                                                 ...
# 886  887,0,2,"Montvila, Rev. Juozas",male,27,0,0,21...
# 887  888,1,1,"Graham, Miss. Margaret Edith",female,...
# 888  889,0,3,"Johnston, Miss. Catherine Helen ""Car...
# 889  890,1,1,"Behr, Mr. Karl Howell",male,26,0,0,11...
# 890  891,0,3,"Dooley, Mr. Patrick",male,32,0,0,3703...
#
# [891 rows x 1 columns]

# %%
titanic = pd.read_csv('ML-datasets/titanic.csv')

# %%
titanic

# %% [markdown]
# Wczytywanie wybranych kolumn

# %%
pd.read_csv('ML-datasets/titanic.csv', usecols=['Survived', "Pclass"])
# Out:
#      Survived  Pclass
# 0           0       3
# 1           1       1
# 2           1       3
# 3           1       1
# 4           0       3
# ..        ...     ...
# 886         0       2
# 887         1       1
# 888         0       3
# 889         1       1
# 890         0       3
#
# [891 rows x 2 columns]

# %% [markdown]
# Wczytywanie df bez nazw kolumn, ich nazwy pojawiają się w pierwszym wierszu

# %%
pd.read_csv('ML-datasets/titanic.csv', header=None) #header=None oznacza, że kolumny będą nr od 0
# Out:
#               0         1       2   \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                     3       4    5      6   \
# 0                                                 Name     Sex  Age  SibSp
# 1                              Braund, Mr. Owen Harris    male   22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                               Heikkinen, Miss. Laina  female   26      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
titanic.columns #wyświetlanie wszystkich nazw kolumn
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Wyświetlanie wartości kolumny jako Series

# %%
titanic['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
titanic[['Pclass', 'Survived']]
# Out:
#      Pclass  Survived
# 0         3         0
# 1         1         1
# 2         3         1
# 3         1         1
# 4         3         0
# ..      ...       ...
# 886       2         0
# 887       1         1
# 888       3         0
# 889       1         1
# 890       3         0
#
# [891 rows x 2 columns]

# %% [markdown]
# Wyświetlanie wierszy wybór numerów

# %%
titanic[10:15]
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 11           12         1       1              Bonnell, Miss. Elizabeth
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
#
#        Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 10  female   4.0      1      1    PP 9549  16.7000    G6        S
# 11  female  58.0      0      0     113783  26.5500  C103        S
# 12    male  20.0      0      0  A/5. 2151   8.0500   NaN        S
# 13    male  39.0      1      5     347082  31.2750   NaN        S
# 14  female  14.0      0      0     350406   7.8542   NaN        S

# %%
titanic.iloc[[10,15],[3,6]] #wybór konkretnych kolumn i wierszy
# Out:
#                                 Name  SibSp
# 10   Sandstrom, Miss. Marguerite Rut      1
# 15  Hewlett, Mrs. (Mary D Kingcome)       0

# %%
titanic.iloc[10:15, 3:6]  #wybór wierszy i kolumn “od do”
# Out:
#                                     Name     Sex   Age
# 10       Sandstrom, Miss. Marguerite Rut  female   4.0
# 11              Bonnell, Miss. Elizabeth  female  58.0
# 12        Saundercock, Mr. William Henry    male  20.0
# 13           Andersson, Mr. Anders Johan    male  39.0
# 14  Vestrom, Miss. Hulda Amanda Adolfina  female  14.0

# %%
titanic.loc[[10,15],["Name"]] # w loc kolumny muszą być po nazwie,a nie nr, jak w iloc
# Out:
#                                 Name
# 10   Sandstrom, Miss. Marguerite Rut
# 15  Hewlett, Mrs. (Mary D Kingcome)

# %% [markdown]
# Wyświetlanie wszystkich kolumn w DataFrame, podgląd wszystkie kolumny

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
titanic

# %% [markdown]
# Filtrowanie wiadomości

# %%
titanic['Age']<20 #true/false

# %%
titanic[titanic['Age']<20] #tu DF

# %%
titanic[(titanic['Sex']=='male') & (titanic['Age']>50)]

# %%
titanic[(titanic['Sex']=='male') | (titanic['Age']<15)] #szukanie elementów o jednym z dwóch argumentów

# %%
titanic.query('Age==20') #jaki warunek mają spełnić wartości w zbiorze, zamiast wpisywania w nawiasy kwadratowe

# %%
titanic.query('Cabin=="A5"') #uwaga na cudzysłowy przy stringach
# Out:
#     PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 96           97         0       1  Goldschmidt, Mr. George B  male  71.0
#
#     SibSp  Parch    Ticket     Fare Cabin Embarked
# 96      0      0  PC 17754  34.6542    A5        C

# %% [markdown]
# Sortowanie wartości

# %%
titanic.sort_values('Name').head(20)

# %% [markdown]
# Tworzenie nowej kolumny/ dodawania nowej kolumny

# %%
titanic['Country']="US"

# %%
titanic[['Nazwisko', 'Imie']]=titanic['Name'].str.split(',', expand=True)# rozdzielanie imienia inazwiska na dwie osobne kolumny za pomocą split

# %%
titanic.head()

# %% [markdown]
# ZLICZANIE DANYCH

# %%
titanic['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# Zliczanie wartości nienullowych w kolumnach

# %%
titanic.count() #widać, że w kolumnie Age, brakuje danych

# %% [markdown]
# Sumowanie wartości w kolumnie

# %%
titanic['Survived'].sum() #suma wartości, NIE REKORDÓW!!!
# Out:
# 342

# %%
titanic['Fare'].min() #max, mean, median
# Out:
# 0.0

# %% [markdown]
# Wyświetlanie wartości unikatowych <br>
# Unique pokazuje wartości na które się najpierw natknie, a set sortuje od A do Z

# %%
titanic['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
set(titanic['Sex'])
# Out:
# {'female', 'male'}

# %%
len(set(titanic['Cabin']))
# Out:
# 148

# %% [markdown]
# Zmiana nazwy kolumny

# %%
titanic.rename(columns={'PassengerId':'number_of_passenger'}, inplace=True)

# %%
titanic.head()
# Out:
#    number_of_passenger  Survived  Pclass  \
# 0                    1         0       3
# 1                    2         1       1
# 2                    3         1       3
# 3                    4         1       1
# 4                    5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_new
# 0      0         A/5 21171   7.2500   NaN        S     24.0
# 1      0          PC 17599  71.2833   C85        C     40.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S     28.0
# ...

# %%
titanic.rename(columns={'Plass':0,'Name':1}, inplace=True)

# %%
titanic.head()
# Out:
#    number_of_passenger  Survived  Pclass  \
# 0                    1         0       3
# 1                    2         1       1
# 2                    3         1       3
# 3                    4         1       1
# 4                    5         0       3
#
#                                                    1     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_new
# 0      0         A/5 21171   7.2500   NaN        S     24.0
# 1      0          PC 17599  71.2833   C85        C     40.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S     28.0
# ...

# %% [markdown]
# USUWANIE DANYCH

# %%
titanic.drop(['Country'], axis=1).head() #usuwanie kolumny bo axis=1!!! oznacza, że idziemy po kolumnach, axis=0 idziemy po wierszach
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Nazwisko  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
titanic.drop(['Age'], axis=1, inplace=True) #żeby powyższa funkcja się nadpisała, używamy inplace

# %%
titanic.sample()
# Out:
#      PassengerId  Survived  Pclass  \
# 167          168         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 167  Skoog, Mrs. William (Anna Bernhardina Karlsson)  female      1      4
#
#      Ticket  Fare Cabin Embarked Country Nazwisko  \
# 167  347088  27.9   NaN        S      US    Skoog
#
#                                           Imie
# 167   Mrs. William (Anna Bernhardina Karlsson)

# %%
titanic.drop(1, axis=0) #usuwanie wiersza 1

# %%
titanic=titanic.loc[titanic['Pclass']!=0] #pozbywanie się wierszy, w którym któraś wartość nam nie pasuje

# %%
titanic.sample()
# Out:
#      PassengerId  Survived  Pclass                Name   Sex  SibSp  Parch  \
# 410          411         0       3  Sdycoff, Mr. Todor  male      0      0
#
#      Ticket    Fare Cabin Embarked Country Nazwisko        Imie
# 410  349222  7.8958   NaN        S      US  Sdycoff   Mr. Todor

# %%
set(titanic['Pclass'])
# Out:
# {1, 2, 3}

# %% [markdown]
# APPLY

# %% [markdown]
# Aplikujemy funkcję dla każdej komórki zbioru

# %%
titanic[['Age', 'Fare']].apply(lambda x: x.max()-x.min()) #lambda to aplikowana funkcja
# Out:
# Age      79.5800
# Fare    512.3292
# dtype: float64

# %% [markdown]
# w tym przypadku dla kolumny ‘Age’ oraz ‘Fare’ wyświetlamy wartość max - min,
# można wyświetlić samo max lub samo min lambda x: x.max()

# %%
titanic['Age_new']=titanic['Age'].apply(lambda x: x+2) #do nowej kolumny Age_new trafiły wartości z kolumny Age + 2( bo x+2)

# %% [markdown]
# GROUPBY
# Grupowanie danych

# %%
titanic.groupby('Pclass')['Age'].mean() #jako output nie otrzymujemy DateFrame. Tu otrzymujemy średni wiek dla pasażerów z każdej klasy
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
titanic.groupby('Pclass', as_index=False)['Age'].mean() #as_index=False, pozwala zapisać jako DateFrame
# Out:
#    Pclass        Age
# 0       1  38.233441
# 1       2  29.877630
# 2       3  25.140620

# %%
titanic.groupby(['Sex', 'Embarked'], as_index=False).count() #zliczanie rekordów
# Out:
#       Sex Embarked  PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  \
# 0  female        C           73        73      73    73   61     73     73
# 1  female        Q           36        36      36    36   12     36     36
# 2  female        S          203       203     203   203  186    203    203
# 3    male        C           95        95      95    95   69     95     95
# 4    male        Q           41        41      41    41   16     41     41
# 5    male        S          441       441     441   441  368    441    441
#
#    Ticket  Fare  Cabin  Age_new
# 0      73    73     37       61
# 1      36    36      2       12
# 2     203   203     56      186
# 3      95    95     32       69
# 4      41    41      2       16
# 5     441   441     73      368

# %%
lista=[1,3,9]

# %%
titanic.groupby('Sex')['Fare'].unique().apply(lambda x: x+2) #dodawanie unikalnych wartości
# Out:
# Sex
# female    [73.2833, 9.925, 55.1, 13.1333, 32.0708, 18.7,...
# male      [9.25, 10.05, 10.4583, 53.8625, 23.075, 33.275...
# Name: Fare, dtype: object

# %% [markdown]
# AGREGOWANIE DANYCH GROUPBY AGGREGATE PANDAS

# %%
titanic.groupby('Sex',as_index=False)['Age'].agg(['sum', 'mean', 'min', 'max'])
# Out:
#              sum       mean   min   max
# Sex
# female   7286.00  27.915709  0.75  63.0
# male    13919.17  30.726645  0.42  80.0

# %% [markdown]
# Agregowanie danych i grupowanie z użyciem słownika

# %%
from numpy.lib.function_base import average
titanic.groupby('Sex').agg(
    {
        'Age':[min, average, max], #słownik jest kluczem, który się zapisuje jako nazwa kolumny ale tylko tutaj 
     'Pclass': [min, max]
    }
)
# Out:
#          Age               Pclass
#          min average   max    min max
# Sex
# female  0.75     NaN  63.0      1   3
# male    0.42     NaN  80.0      1   3

# %%
#II opcja:
titanic.groupby('Sex').agg(
    Age=('Age', max),
    count_survived=('Survived', sum)
)
# Out:
#          Age  count_survived
# Sex
# female  63.0             233
# male    80.0             109

# %% [markdown]
# WARTOŚCI NULLOWE

# %%
titanic.isna() #czy wartość jest brakująca, jeśli wyświetli się False to jest nienullowa, czyli znamy wartość

# %% [markdown]
# Usuwanie danych/ Wartości brakujące

# %%
titanic.drop([1], axis=1) #jako parametr podajemy spis indexów lub kolumn do usunięcia oraz axis - czy ma być usunięty index czy kolumna.

# %%
titanic.drop([1,2]) #bez axis też działa

# %% [markdown]
# DROPNA - uwuwa Nany

# %%
titanic.dropna(how='any')#usuwanie wierszy, w których wystąpił NaN

# %%
titanic.dropna(how='all') #usuwanie wierszy, w których we wszystkich komórkach mamy NaN

# %%
titanic.dropna(how='any', axis=1) #usuwanie kolumn z brakującymi wartościami

# %%
df=df.dropna(subset=['korzysta_z_reklam']) #usuwanie NaN z konkretnej kolumny!!!

# %% [markdown]
# Funkcja FILLNA pozwala na wypełnienie wartości brakujących

# %%
titanic['Age'].fillna(titanic['Age'].mean())#wypełnianie wartości brakujących

# %%
titanic['Age'].fillna(0)

# %%
titanic['Cabin_new']=titanic['Cabin'].fillna('')

# %% [markdown]
# Wprowadzenie nowych wartości w miejsce Nanów - cechy kategoryczne

# %%
titanic['Cabin'].fillna(titanic['Cabin'].value_counts(), inplace=True)

# %%
titanic.head()
# Out:
#    number_of_passenger  Survived  Pclass  \
# 0                    1         0       3
# 1                    2         1       1
# 2                    3         1       3
# 3                    4         1       1
# 4                    5         0       3
#
#                                                    1     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_new Cabin_new
# 0      0         A/5 21171   7.2500   NaN        S     24.0
# 1      0          PC 17599  71.2833   C85        C     40.0       C85
# 2      0  STON/O2. 3101282   7.9250   NaN        S     28.0
# ...

# %% [markdown]
# #Sprawdzanie rozkładu zmiennej

# %%
import matplotlib.pyplot as plt
from scipy import stats

# %%
plt.hist(titanic['Age'])  #wydruk kolumny w postaci wykresu, sprawdzamy czy dane ,mają charakter normalny, bo do niego dążymy
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# TEST SHAPIRO-WILKA<br>
# Test Shapiro-Wilka – test służący do oceny, czy zebrane przez nas wyniki od badanych osób posiadają rozkład normalny. Hipoteza zerowa dla tego testu zakłada, że nasza próba badawcza pochodzi z populacji o normalnym rozkładzie. Jeśli test Shapiro-Wilka osiąga istotność statystyczną (p < 0,05), świadczy to o rozkładzie odbiegającym od krzywej Gaussa.

# %%
shapiro_test_fare=stats.shapiro(titanic['Fare'])

# %%
shapiro_test_fare
# Out:
# ShapiroResult(statistic=0.5218917727470398, pvalue=1.0789998175301091e-43)

# %% [markdown]
# Transformacja<br>
# Funkcja Numpy log() pomaga użytkownikowi obliczyć Logarytm naturalny x gdzie x należy do wszystkich elementów tablicy wejściowej.

# %% [markdown]
# TRANSFORMACJA LOGARYTMICZNA
# * pomaga poradzić sobie z wypaczonymi danymi
# * porządkuje wielkość danych
# * zmniejsza wpływ wartości odstających
# * zwiększa niezawodność modelu
# * trzeba zająć się wartościami ujemnymi

# %%
import numpy as np

# %%
titanic['log_fare']=np.log(titanic['Fare'])
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# INNY PRZYKŁAD

# %%
data = pd.DataFrame({'value': [2,45,-23, 85, 28, 2, 35, 12]})

# %%
data['log+1'] = (data['value']+1).transform(np.log) #czyli log(x+1)

# %%
data
# Out:
#    value     log+1
# 0      2  1.098612
# 1     45  3.828641
# 2    -23       NaN
# 3     85  4.454347
# 4     28  3.367296
# 5      2  1.098612
# 6     35  3.583519
# 7     12  2.564949

# %%
data['log'] = (data['value'] -data['value'].min()+1).transform(np.log) #czyli, log(x-min(x)+1)

# %%
data
# Out:
#    value     log+1       log
# 0      2  1.098612  3.258097
# 1     45  3.828641  4.234107
# 2    -23       NaN  0.000000
# 3     85  4.454347  4.691348
# 4     28  3.367296  3.951244
# 5      2  1.098612  3.258097
# 6     35  3.583519  4.077537
# 7     12  2.564949  3.583519

# %%
titanic.query('Fare==0').head()
# Out:
#      number_of_passenger  Survived  Pclass                                1  \
# 179                  180         0       3              Leonard, Mr. Lionel
# 263                  264         0       1            Harrison, Mr. William
# 271                  272         1       3     Tornquist, Mr. William Henry
# 277                  278         0       2      Parkes, Mr. Francis "Frank"
# 302                  303         0       3  Johnson, Mr. William Cahoone Jr
#
#       Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  Age_new Cabin_new  \
# 179  male  36.0      0      0    LINE   0.0   NaN        S     38.0
# 263  male  40.0      0      0  112059   0.0   B94        S     42.0       B94
# 271  male  25.0      0      0    LINE   0.0   NaN        S     27.0
# 277  male   NaN      0      0  239853   0.0   NaN        S      NaN
# 302  male  19.0      0      0    LINE   0.0   NaN        S     21.0
#
#      log_fare
# 179      -inf
# 263      -inf
# 271      -inf
# 277      -inf
# ...

# %% [markdown]
# WARTOŚCI NIESKOŃCZONOŚCI INF

# %%
plt.hist(titanic[np.isfinite(titanic['log_fare'])]['log_fare'])
# Out:
# (array([  7., 342., 132., 143.,  81.,  74.,  55.,  22.,  17.,   3.]),
#  array([1.38941449, 1.87436978, 2.35932507, 2.84428036, 3.32923565,
#         3.81419094, 4.29914623, 4.78410152, 5.26905681, 5.7540121 ,
#         6.23896739]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Usuwanie wartości odstających za pomocą odchylenia standardowego

# %%
titanic['Fare'].mean()
# Out:
# 32.204207968574636

# %%
titanic['Fare'].std()
# Out:
# 49.6934285971809

# %%
upper=titanic['Fare'].mean()+titanic['Fare'].std()*3

# %%
upper
# Out:
# 181.2844937601173

# %%
lower=titanic['Fare'].mean()-titanic['Fare'].std()*3

# %%
lower
# Out:
# -116.87607782296804

# %%
titanic2=titanic[(titanic['Fare']<upper) & (titanic['Fare']>lower)]

# %%
plt.hist(titanic2['Fare'])#wyświetlenie wykresu
# Out:
# (array([494., 188.,  45.,  48.,  45.,  18.,  11.,   4.,   9.,   9.]),
#  array([  0.     ,  16.48667,  32.97334,  49.46001,  65.94668,  82.43335,
#          98.92002, 115.40669, 131.89336, 148.38003, 164.8667 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Usuwanie wartości odstających za pomocą percentyli

# %%
upper=titanic['Fare'].quantile(.95)

# %%
upper
# Out:
# 112.07915

# %%
lower=titanic['Fare'].quantile(.05)

# %%
lower
# Out:
# 7.225

# %%
titanic3=titanic[(titanic['Fare']<upper)& (titanic['Fare']>lower)]

# %%
plt.hist(titanic3['Fare'])
# Out:
# (array([442., 142.,  62.,  26.,  41.,  11.,  36.,  19.,   4.,   8.]),
#  array([  7.2292 ,  17.59461,  27.96002,  38.32543,  48.69084,  59.05625,
#          69.42166,  79.78707,  90.15248, 100.51789, 110.8833 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Dyskretyzacja - zamienianie zmiennych ciągłych na kategorie

# %%
wiek = []
for i in  range(len(titanic)):
  if titanic['Age'][i]<30:
    wiek.append('young')
  else:
    wiek.append('old')

# %%
wiek

# %% [markdown]
# LUB!!!!! pd.cut

# %%
titanic['age_cat1']=wiek

# %%
titanic.head()
# Out:
#    number_of_passenger  Survived  Pclass  \
# 0                    1         0       3
# 1                    2         1       1
# 2                    3         1       3
# 3                    4         1       1
# 4                    5         0       3
#
#                                                    1     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_new Cabin_new  \
# 0      0         A/5 21171   7.2500   NaN        S     24.0
# 1      0          PC 17599  71.2833   C85        C     40.0       C85
# 2      0  STON/O2. 3101282   7.9250   NaN        S     28.0
# ...

# %%
titanic['age_cat1'].value_counts() #zliczanie wartości w kolumnie, tu ile jest young ile old
# Out:
# old      507
# young    384
# Name: age_cat1, dtype: int64

# %%
titanic['age_cat3']=pd.cut(titanic['Age'],bins=[0,30, 100], labels=['young', 'old']) #tu przypisujemy do etykiet. Szybsza wersja zapisu w pętli

# %%
titanic.head()
# Out:
#       Sex
# 0    male
# 1  female
# 2  female
# 3  female
# 4    male

# %% [markdown]
# ONE HOT ENCODING<br>
# Konwertuje dane typu string na dane numeryczne 0 i 1

# %%
pclass_onehot=pd.get_dummies(titanic['Pclass'])

# %%
pclass_onehot

# %%
pd.get_dummies(titanic['Sex']).head(5)
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %% [markdown]
# Łączenie zbiorów danych

# %%
df1 = pd.DataFrame({'animal': ['dog', 'cat', 'pig', 'cow'], 'age': [1,2,3,4]})
df2 = pd.DataFrame({'animal': ['dog', 'parrot', 'pig', 'cow', 'horse'], 'eat': [2,2,4,5,3]})

# %%
df1.append(['chamster', 6])
# Out:
# <ipython-input-170-77df75cf71af>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(['chamster', 6])
#   animal  age         0
# 0    dog  1.0       NaN
# 1    cat  2.0       NaN
# 2    pig  3.0       NaN
# 3    cow  4.0       NaN
# 0    NaN  NaN  chamster
# 1    NaN  NaN         6

# %%
df1
# Out:
#   animal  age
# 0    dog    1
# 1    cat    2
# 2    pig    3
# 3    cow    4
